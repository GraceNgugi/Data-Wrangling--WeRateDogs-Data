# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# ### ANALYZING AND VISUALIZING DATA
# In this section we are required to analyzing data by coming up with some questions and trying to draw insights from the results.
# The three insights and visualization done in the merged dataset is present below.

# %% [markdown]
# ***1. Is there a correlation between the retweet counf and favorite count.***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***Insight***
#
# There is a positive correlation between the retweet count and favorite count.As favorite tweet increases the retweet count increase as well and as the favorite tweet decreases the retweet count will decrease.

# %% [markdown]
# ***2. Most popular dog stage and the percenatges of dogs.***

# %% [markdown]
# ![img3.PNG](attachment:img3.PNG)

# %% [markdown]
# ***Insights***
#
# 1. From this analysis pupper has 66.4% which is the highest percentage meaning it is the most popular dog stage.
# 2. Floofer has the lowest percentage with 1.0%.

# %% [markdown]
# ***3. Determine the Most used kind of device***

# %% [markdown]
# ![img2.PNG](attachment:img2.PNG)

# %% [markdown]
# ***Insight***
#
# The most kind of device used for tweets based on the number of tweetsis Twitter for iphone,followed by vine-make a scene then the twitter web client and the least been TweetDeck.
# This shows that most people use twitter for iphone.
